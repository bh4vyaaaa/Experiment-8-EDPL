# %% [markdown]
# <a href="https://colab.research.google.com/github/bh4vyaaaa/Experiment-8-EDPL/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Experiment No.8
# ## Tools for EDA - Numpy
# ### Bhavya Pandya
# ### 25070123139
# ### E&TC A1

# %% [markdown]
# # Why Numpy?
# ## Faster than lists
# ## Used for Numerical Calculations
# ### Base for Pandas[link text](https://)

# %%
import numpy as np
a = np.array([10,20,30,40])
b = np.array([[1,2,3,], [4,5,6]])
print(a)
print(b)
# Out:
# [10 20 30 40]
# [[1 2 3]
#  [4 5 6]]

# %%
a.ndim
# Out:
# 1

# %%
b.ndim
# Out:
# 2

# %%
a.shape
b.shape
# Out:
# (2, 3)

# %%
a.dtype
# Out:
# dtype('int64')

# %%
np.zeros((2,3))
# Out:
# array([[0., 0., 0.],
#        [0., 0., 0.]])

# %%
np.ones((3,3))
# Out:
# array([[1., 1., 1.],
#        [1., 1., 1.],
#        [1., 1., 1.]])

# %%
np.eye((3))
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %%
np.arange(1,8,3)
# Out:
# array([1, 4, 7])

# %%
np.linspace(0,2,6)
# Out:
# array([0. , 0.4, 0.8, 1.2, 1.6, 2. ])

# %%
# Only the 2nd input is printed as default
a + 6
a * 3
# Out:
# array([ 30,  60,  90, 120])

# %%
a + 6
# Out:
# array([16, 26, 36, 46])

# %%
# If both needed to be printed in same code:-
c = a*3
d = a*5
print(c)
print(d)
# Out:
# [ 30  60  90 120]
# [ 50 100 150 200]

# %%
np.mean(a)
# Out:
# np.float64(25.0)

# %%
# if mean and median are same your data has no outliars()
np.median(b)
# Out:
# np.float64(3.5)

# %%
np.max(a)
# Out:
# np.int64(40)

# %%
np.max(b)
# Out:
# np.int64(6)

# %%
np.min(a)
# Out:
# np.int64(10)

# %%
np.min(b)
# Out:
# np.int64(1)

# %%
np.sum(a)
# Out:
# np.int64(100)

# %%
np.sum(b)
# Out:
# np.int64(21)
